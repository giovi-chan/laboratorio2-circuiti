# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Aprire il file in modalità di lettura
with open('err_casuale fase 1k.txt', 'r') as file:
    # Leggere tutte le righe del file
    lines = file.readlines()

# Inizializzare le liste per memorizzare i dati
x_values = []
y_values = []

# Iterare attraverso le righe e estrarre i dati
for line in lines:
    # Dividere la riga in base agli spazi
    parts = line.split()
    # Convertire i valori in numeri reali e aggiungerli alle rispettive liste
    x_values.append(float(parts[0]))
    y_values.append(float(parts[1]))
    
    
# for i, y in enumerate(y_values):
#     if y < 0:
#         y_values[i] += 360
        
for i, y in enumerate(y_values):
    if y > 180:
        y_values.remove(y_values[i])
        x_values.remove(x_values[i])
   

    
    
# Definire la funzione gaussiana
def gaussian(x, amplitude, mean, sigma):
    return amplitude * np.exp(-((x - mean) / sigma) ** 2 / 2)

# Calcolare l'istogramma dei dati
num_bins = 50

hist, bin_edges = np.histogram(y_values, bins=num_bins, density=True)
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# Esegui il fit della gaussiana
param_bounds = ([0, min(y_values), 0], [8, max(y_values), 10])
popt, pcov = curve_fit(gaussian, bin_centers, hist, bounds=param_bounds, maxfev =70000)

# Estrai i parametri ottimizzati
amplitude_fit, mean_fit, stddev_fit = popt

# Visualizza i dati e il fit
plt.hist(y_values, bins=num_bins, density=True, label='Data')
plt.plot(bin_centers, gaussian(bin_centers, *popt), color='red', label='Gaussian Fit')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Fit con una funzione gaussiana')
plt.legend()
plt.show()

# Calcola i valori predetti dal modello ai punti x_values
y_predicted = gaussian(x_values, *popt)

# Calcola l'errore associato a ciascun punto (puoi usare la deviazione standard dei dati)
errors = stddev_fit
print(stddev_fit)
print(mean_fit)

# Calcola il chi-quadro
chi_squared = np.sum(((y_values - y_predicted) / errors)**2)

print("Chi-squared:", chi_squared)
# Out:
# 0.06632423844853702
# -2.9658623948941263
# Chi-squared: 705027.0020984939

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Aprire il file in modalità di lettura
with open('err_casuale fase 8k.txt', 'r') as file:
    # Leggere tutte le righe del file
    lines = file.readlines()

# Inizializzare le liste per memorizzare i dati
x_values = []
y_values = []

# Iterare attraverso le righe e estrarre i dati
for line in lines:
    # Dividere la riga in base agli spazi
    parts = line.split()
    # Convertire i valori in numeri reali e aggiungerli alle rispettive liste
    x_values.append(float(parts[0]))
    y_values.append(float(parts[1]))
    
for i, y in enumerate(y_values):
    if y < 0:
        y_values[i] += 360

    
    
# Definire la funzione gaussiana
def gaussian(x, amplitude, mean, sigma):
    return amplitude * np.exp(-((x - mean) / sigma) ** 2 / 2)

# Calcolare l'istogramma dei dati
num_bins = 40

hist, bin_edges = np.histogram(y_values, bins=num_bins, density=True)
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# Esegui il fit della gaussiana
param_bounds = ([0, min(y_values), 0], [3500, max(y_values), 1])
popt, pcov = curve_fit(gaussian, bin_centers, hist, bounds=param_bounds, maxfev =70000)

# Estrai i parametri ottimizzati
amplitude_fit, mean_fit, stddev_fit = popt

# Visualizza i dati e il fit
plt.hist(y_values, bins=num_bins, density=True, label='Data')
plt.plot(bin_centers, gaussian(bin_centers, *popt), color='red', label='Gaussian Fit')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Fit con una funzione gaussiana')
plt.legend()
plt.show()

# Calcola i valori predetti dal modello ai punti x_values
y_predicted = gaussian(x_values, *popt)

# Calcola l'errore associato a ciascun punto (puoi usare la deviazione standard dei dati)
errors = stddev_fit
print(stddev_fit)
print(mean_fit)

# Calcola il chi-quadro
chi_squared = np.sum(((y_values - y_predicted) / errors)**2)

print("Chi-squared:", chi_squared)
# Out:
# 0.11033294776705409
# 3.1446357533052596
# Chi-squared: 427421.00028983573

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Aprire il file in modalità di lettura
with open('err_casuale fase 16k.txt', 'r') as file:
    # Leggere tutte le righe del file
    lines = file.readlines()

# Inizializzare le liste per memorizzare i dati
x_values = []
y_values = []

# Iterare attraverso le righe e estrarre i dati
for line in lines:
    # Dividere la riga in base agli spazi
    parts = line.split()
    # Convertire i valori in numeri reali e aggiungerli alle rispettive liste
    x_values.append(float(parts[0]))
    y_values.append(float(parts[1]))
    
for i, y in enumerate(y_values):
    if y < 0:
        y_values[i] += 360

    
    
# Definire la funzione gaussiana
def gaussian(x, amplitude, mean, sigma):
    return amplitude * np.exp(-((x - mean) / sigma) ** 2 / 2)

# Calcolare l'istogramma dei dati
num_bins = 40

hist, bin_edges = np.histogram(y_values, bins=num_bins, density=True)
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# Esegui il fit della gaussiana
param_bounds = ([0, min(y_values), 0], [3500, max(y_values), 1])
popt, pcov = curve_fit(gaussian, bin_centers, hist, bounds=param_bounds, maxfev =70000)

# Estrai i parametri ottimizzati
amplitude_fit, mean_fit, stddev_fit = popt

# Visualizza i dati e il fit
plt.hist(y_values, bins=num_bins, density=True, label='Data')
plt.plot(bin_centers, gaussian(bin_centers, *popt), color='red', label='Gaussian Fit')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Fit con una funzione gaussiana')
plt.legend()
plt.show()

# Calcola i valori predetti dal modello ai punti x_values
y_predicted = gaussian(x_values, *popt)

# Calcola l'errore associato a ciascun punto (puoi usare la deviazione standard dei dati)
errors = stddev_fit
print(stddev_fit)
print(mean_fit)

# Calcola il chi-quadro
chi_squared = np.sum(((y_values - y_predicted) / errors)**2)

print("Chi-squared:", chi_squared)
# Out:
# 0.13378745255936625
# 2.565503475680543
# Chi-squared: 218093.00401138578

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Aprire il file in modalità di lettura
with open('err_casuale fase 23k.txt', 'r') as file:
    # Leggere tutte le righe del file
    lines = file.readlines()

# Inizializzare le liste per memorizzare i dati
x_values = []
y_values = []

# Iterare attraverso le righe e estrarre i dati
for line in lines:
    # Dividere la riga in base agli spazi
    parts = line.split()
    # Convertire i valori in numeri reali e aggiungerli alle rispettive liste
    x_values.append(float(parts[0]))
    y_values.append(float(parts[1]))
    
for i, y in enumerate(y_values):
    if y < 0:
        y_values[i] += 360

    
    
# Definire la funzione gaussiana
def gaussian(x, amplitude, mean, sigma):
    return amplitude * np.exp(-((x - mean) / sigma) ** 2 / 2)

# Calcolare l'istogramma dei dati
num_bins = 40

hist, bin_edges = np.histogram(y_values, bins=num_bins, density=True)
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# Esegui il fit della gaussiana
param_bounds = ([0, min(y_values), 0], [3500, max(y_values), 1])
popt, pcov = curve_fit(gaussian, bin_centers, hist, bounds=param_bounds, maxfev =70000)

# Estrai i parametri ottimizzati
amplitude_fit, mean_fit, stddev_fit = popt

# Visualizza i dati e il fit
plt.hist(y_values, bins=num_bins, density=True, label='Data')
plt.plot(bin_centers, gaussian(bin_centers, *popt), color='red', label='Gaussian Fit')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Fit con una funzione gaussiana')
plt.legend()
plt.show()

# Calcola i valori predetti dal modello ai punti x_values
y_predicted = gaussian(x_values, *popt)

# Calcola l'errore associato a ciascun punto (puoi usare la deviazione standard dei dati)
errors = stddev_fit
print(stddev_fit)
print(mean_fit)

# Calcola il chi-quadro
chi_squared = np.sum(((y_values - y_predicted) / errors)**2)

print("Chi-squared:", chi_squared)
# Out:
# 0.1775604106854469
# 356.95749566765573
# Chi-squared: 2372341748.6755247

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Aprire il file in modalità di lettura
with open('err_casuale fase 40k.txt', 'r') as file:
    # Leggere tutte le righe del file
    lines = file.readlines()

# Inizializzare le liste per memorizzare i dati
x_values = []
y_values = []

# Iterare attraverso le righe e estrarre i dati
for line in lines:
    # Dividere la riga in base agli spazi
    parts = line.split()
    # Convertire i valori in numeri reali e aggiungerli alle rispettive liste
    x_values.append(float(parts[0]))
    y_values.append(float(parts[1]))
    
for i, y in enumerate(y_values):
    if y < 0:
        y_values[i] += 360

    
    
# Definire la funzione gaussiana
def gaussian(x, amplitude, mean, sigma):
    return amplitude * np.exp(-((x - mean) / sigma) ** 2 / 2)

# Calcolare l'istogramma dei dati
num_bins = 40

hist, bin_edges = np.histogram(y_values, bins=num_bins, density=True)
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# Esegui il fit della gaussiana
param_bounds = ([0, min(y_values), 0], [3500, max(y_values), 1])
popt, pcov = curve_fit(gaussian, bin_centers, hist, bounds=param_bounds, maxfev =70000)

# Estrai i parametri ottimizzati
amplitude_fit, mean_fit, stddev_fit = popt

# Visualizza i dati e il fit
plt.hist(y_values, bins=num_bins, density=True, label='Data')
plt.plot(bin_centers, gaussian(bin_centers, *popt), color='red', label='Gaussian Fit')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Fit con una funzione gaussiana')
plt.legend()
plt.show()

# Calcola i valori predetti dal modello ai punti x_values
y_predicted = gaussian(x_values, *popt)

# Calcola l'errore associato a ciascun punto (puoi usare la deviazione standard dei dati)
errors = stddev_fit
print(stddev_fit)
print(mean_fit)

# Calcola il chi-quadro
chi_squared = np.sum(((y_values - y_predicted) / errors)**2)

print("Chi-squared:", chi_squared)
# Out:
# 0.26890818847723524
# 10.00231903533319
# Chi-squared: 820849.758263422

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit


# Aprire il file in modalità di lettura
with open('err_sis V_S.txt', 'r') as file:
    # Leggere tutte le righe del file
    lines = file.readlines()

# Inizializzare le liste per memorizzare i dati
x_values = []
y_values = []

# Iterare attraverso le righe e estrarre i dati
for line in lines:
    # Dividere la riga in base agli spazi
    parts = line.split()
    # Convertire i valori in numeri reali e aggiungerli alle rispettive liste
    x_values.append(float(parts[0]))
    y_values.append(float(parts[1]))
    
# for i, y in enumerate(y_values):
#     if y < 0:
#         y_values[i] += 360

# Converti x_values in un array numpy
    
# Definire la funzione lineare di fit
def linear(x, a, b):
    return a*x +b

# Esegui il fit della retta
param_bounds = ([0, -10], [1, 1])
popt, pcov = curve_fit(linear, x_values, y_values, bounds=param_bounds, maxfev =70000)



# Estrai i parametri ottimizzati
slope_fit, offset_fit = popt

# Visualizza i dati e il fit

plt.scatter(x_values, y_values, s= 2, label='Dati sperimentali')

x_values = np.array(x_values)

plt.plot(x_values, linear(x_values, *popt), color='red', label='Linear Fit')
plt.xlabel('Frequency')
plt.ylabel('Phase')
plt.title('Linear fit')
plt.legend()
plt.show()

# Calcola i valori predetti dal modello ai punti x_values
y_predicted = linear(x_values, *popt)

# Calcola l'errore associato a ciascun punto (puoi usare la deviazione standard dei dati)
errors = np.array([0.23] * len(y_values))

# Calcola il chi-quadro
chi_squared = np.sum(((y_values - y_predicted) / errors)**2)/114.

print ('Slope: ', slope_fit, '\nOffset: ', offset_fit)

print("\nChi-squared-red:", chi_squared)
# Out:
# Slope:  6.314211620158034e-05
# Offset:  -2.652002343301433
#
# Chi-squared-red: 1.0714974407016264

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit


# Aprire il file in modalità di lettura
with open('errore sistematico fase V_S.txt', 'r') as file:
    # Leggere tutte le righe del file
    lines = file.readlines()

# Inizializzare le liste per memorizzare i dati
x_values = []
y_values = []

# Iterare attraverso le righe e estrarre i dati
for line in lines:
    # Dividere la riga in base agli spazi
    parts = line.split()
    # Convertire i valori in numeri reali e aggiungerli alle rispettive liste
    x_values.append(float(parts[0]))
    y_values.append(float(parts[1]))
    
    
# Definire la funzione lineare di fit
def linear(x, a, b):
    return a*x +b

# Esegui il fit della retta
param_bounds = ([0, -10], [1, 1])
popt, pcov = curve_fit(linear, x_values, y_values, bounds=param_bounds, maxfev =70000)



# Estrai i parametri ottimizzati
slope_fit, offset_fit = popt

# Visualizza i dati e il fit

plt.scatter(x_values, y_values, s= 2, label='Dati sperimentali')

x_values = np.array(x_values)

plt.plot(x_values, linear(x_values, *popt), color='red', label='Linear Fit')
plt.xlabel('Frequency')
plt.ylabel('Phase')
plt.title('Linear fit')
plt.legend()
plt.show()

# Calcola i valori predetti dal modello ai punti x_values
y_predicted = linear(x_values, *popt)

# Calcola l'errore associato a ciascun punto (puoi usare la deviazione standard dei dati)
errors = np.array([0.23] * len(y_values))

# Calcola il chi-quadro
chi_squared = np.sum(((y_values - y_predicted) / errors)**2)/114.

print ('Slope: ', slope_fit, '\nOffset: ', offset_fit)

print("\nChi-squared-red:", chi_squared)
# Out:
# Slope:  6.20932558310695e-05
# Offset:  -2.6990047849767658
#
# Chi-squared-red: 0.591429503293832

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit


# Aprire il file in modalità di lettura
with open('err_sis V_R.txt', 'r') as file:
    # Leggere tutte le righe del file
    lines = file.readlines()

# Inizializzare le liste per memorizzare i dati
x_values = []
y_values = []

# Iterare attraverso le righe e estrarre i dati
for line in lines:
    # Dividere la riga in base agli spazi
    parts = line.split()
    # Convertire i valori in numeri reali e aggiungerli alle rispettive liste
    x_values.append(float(parts[0]))
    y_values.append(float(parts[1]))
    
    
# Definire la funzione lineare di fit
def linear(x, a, b):
    return a*x +b

# Esegui il fit della retta
param_bounds = ([0, -10], [2, 2])
popt, pcov = curve_fit(linear, x_values, y_values, bounds=param_bounds, maxfev =70000)


# Estrai i parametri ottimizzati
slope_fit, offset_fit = popt

# Visualizza i dati e il fit

plt.scatter(x_values, y_values, s= 2, label='Dati sperimentali')

x_values = np.array(x_values)

plt.plot(x_values, linear(x_values, *popt), color='red', label='Linear Fit')
plt.xlabel('Frequency')
plt.ylabel('Phase')
plt.title('Linear fit')
plt.legend()
plt.show()

# Calcola i valori predetti dal modello ai punti x_values
y_predicted = linear(x_values, *popt)

# Calcola l'errore associato a ciascun punto (puoi usare la deviazione standard dei dati)
errors = np.array([0.23] * len(y_values))

# Calcola il chi-quadro
chi_squared = np.sum(((y_values - y_predicted) / errors)**2)/117.

print ('Slope: ', slope_fit, '\nOffset: ', offset_fit)

print("\nChi-squared-red:", chi_squared)
# Out:
# Slope:  0.00028198409330438157
# Offset:  -2.695525201755178
#
# Chi-squared-red: 0.6341509025877354

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit


# Aprire il file in modalità di lettura
with open('err_sis V_C.txt', 'r') as file:
    # Leggere tutte le righe del file
    lines = file.readlines()

# Inizializzare le liste per memorizzare i dati
x_values = []
y_values = []

# Iterare attraverso le righe e estrarre i dati
for line in lines:
    # Dividere la riga in base agli spazi
    parts = line.split()
    # Convertire i valori in numeri reali e aggiungerli alle rispettive liste
    x_values.append(float(parts[0]))
    y_values.append(float(parts[1]))
    

    
# Definire la funzione lineare di fit
def linear(x, a, b):
    return a*x +b

# Esegui il fit della retta
param_bounds = ([0, -10], [2, 2])
popt, pcov = curve_fit(linear, x_values, y_values, bounds=param_bounds, maxfev =70000)


# Estrai i parametri ottimizzati
slope_fit, offset_fit = popt

# Visualizza i dati e il fit

plt.scatter(x_values, y_values, s= 2, label='Dati sperimentali')

x_values = np.array(x_values)

plt.plot(x_values, linear(x_values, *popt), color='red', label='Linear Fit')
plt.xlabel('Frequency')
plt.ylabel('Phase')
plt.title('Linear fit')
plt.legend()
plt.show()

# Calcola i valori predetti dal modello ai punti x_values
y_predicted = linear(x_values, *popt)

# Calcola l'errore associato a ciascun punto (puoi usare la deviazione standard dei dati)
errors = np.array([0.23] * len(y_values))

# Calcola il chi-quadro
chi_squared = np.sum(((y_values - y_predicted) / errors)**2)/114.

print ('Slope: ', slope_fit, '\nOffset: ', offset_fit)

print("\nChi-squared-red:", chi_squared)
# Out:
# Slope:  0.0005190482608014763
# Offset:  -2.7418858407741813
#
# Chi-squared-red: 0.750688417446597

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit


# Aprire il file in modalità di lettura
with open('errore sistematico fase V_C.txt', 'r') as file:
    # Leggere tutte le righe del file
    lines = file.readlines()

# Inizializzare le liste per memorizzare i dati
x_values = []
y_values = []

# Iterare attraverso le righe e estrarre i dati
for line in lines:
    # Dividere la riga in base agli spazi
    parts = line.split()
    # Convertire i valori in numeri reali e aggiungerli alle rispettive liste
    x_values.append(float(parts[0]))
    y_values.append(float(parts[1]))
    
# for i, y in enumerate(y_values):
#     if y < 0:
#         y_values[i] += 360

# Converti x_values in un array numpy
    
# Definire la funzione lineare di fit
def linear(x, a, b):
    return a*x +b

# Esegui il fit della retta
param_bounds = ([0, -10], [2, 2])
popt, pcov = curve_fit(linear, x_values, y_values, bounds=param_bounds, maxfev =70000)


# Estrai i parametri ottimizzati
slope_fit, offset_fit = popt

# Visualizza i dati e il fit

plt.scatter(x_values, y_values, s= 2, label='Dati sperimentali')

x_values = np.array(x_values)

plt.plot(x_values, linear(x_values, *popt), color='red', label='Linear Fit')
plt.xlabel('Frequency')
plt.ylabel('Phase')
plt.title('Linear fit')
plt.legend()
plt.show()

# Calcola i valori predetti dal modello ai punti x_values
y_predicted = linear(x_values, *popt)

# Calcola l'errore associato a ciascun punto (puoi usare la deviazione standard dei dati)
errors = np.array([0.23] * len(y_values))

# Calcola il chi-quadro
chi_squared = np.sum(((y_values - y_predicted) / errors)**2)/116.

print ('Slope: ', slope_fit, '\nOffset: ', offset_fit)

print("\nChi-squared-red:", chi_squared)
# Out:
# Slope:  0.000515505214707567
# Offset:  -2.6985611715173903
#
# Chi-squared-red: 0.6892633858855902
